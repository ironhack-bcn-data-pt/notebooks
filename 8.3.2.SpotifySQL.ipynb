# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Save-to-DB" data-toc-modified-id="Save-to-DB-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Save to DB</a></span></li><li><span><a href="#Albums" data-toc-modified-id="Albums-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Albums</a></span></li><li><span><a href="#Tracks" data-toc-modified-id="Tracks-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Tracks</a></span></li></ul></div>

# %%
import spotipy

# %%
import pandas as pd
import numpy as np

# %%
with open('../../9_Credentials/spotify.json') as f:
    credentials = json.load(f)

# %%
client_id = credentials['client_id']
client_secret = credentials['client_secret']

# %%
from spotipy.oauth2 import SpotifyClientCredentials

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id, client_secret))

# %%
sp.search('Bruce Springsteen', limit=50)

# %%
res = sp.search('Kaya', type='album', limit=50)

# %%
res
# Out:
# {'albums': {'href': 'https://api.spotify.com/v1/search?query=Kaya&type=album&offset=0&limit=50',
#   'items': [{'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2QsynagSdAqZj3U9HgDzjD'},
#       'href': 'https://api.spotify.com/v1/artists/2QsynagSdAqZj3U9HgDzjD',
#       'id': '2QsynagSdAqZj3U9HgDzjD',
#       'name': 'Bob Marley & The Wailers',
#       'type': 'artist',
#       'uri': 'spotify:artist:2QsynagSdAqZj3U9HgDzjD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
# ...

# %%
res = sp.search('Bruce Springsteen', limit=50)

# %%
bob_marley= '2QsynagSdAqZj3U9HgDzjD'

# %%
bruce_sprinsteen = '3eqjTLE0HfPfh78zjh6TqT'

# %%
a = sp.artist(bruce_sprinsteen)

# %%
a
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/3eqjTLE0HfPfh78zjh6TqT'},
#  'followers': {'href': None, 'total': 3946184},
#  'genres': ['classic rock',
#   'heartland rock',
#   'mellow gold',
#   'permanent wave',
#   'rock',
#   'singer-songwriter'],
#  'href': 'https://api.spotify.com/v1/artists/3eqjTLE0HfPfh78zjh6TqT',
#  'id': '3eqjTLE0HfPfh78zjh6TqT',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/22fbfc9f6b2c61c5ca379847d904bfd0b2cc0dc2',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/22c6a1ac3a0ae7896ebe464f0445e391633df455',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/25ec2d865330b67dc01962fe4ca92039382a0e5b',
#    'width': 160}],
#  'name': 'Bruce Springsteen',
#  'popularity': 80,
#  'type': 'artist',
#  'uri': 'spotify:artist:3eqjTLE0HfPfh78zjh6TqT'}

# %%
a['name']
# Out:
# 'Bruce Springsteen'

# %%
album['id']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-d2e722d98580> in <module>
# ----> 1 album['id']
#
# NameError: name 'album' is not defined

# %%
a['images'][0]['url']
# Out:
# 'https://i.scdn.co/image/22fbfc9f6b2c61c5ca379847d904bfd0b2cc0dc2'

# %%
a['followers']['total']
# Out:
# 3932724

# %%
b = sp.artist(bob_marley)

# %%
artist_df = pd.DataFrame([{'id': a['id'],
                'name': a['name'],
                'photo': a['images'][0]['url'],
                'followers':a['followers']['total']},
                {'id': b['id'],
                'name': b['name'],
                'photo': b['images'][0]['url'],
                'followers':b['followers']['total']}])

# %%
artist_df
# Out:
#                        id                      name  \
# 0  3eqjTLE0HfPfh78zjh6TqT         Bruce Springsteen
# 1  2QsynagSdAqZj3U9HgDzjD  Bob Marley & The Wailers
#
#                                                photo  followers
# 0  https://i.scdn.co/image/22fbfc9f6b2c61c5ca3798...    3946184
# 1  https://i.scdn.co/image/b5aae2067db80f694a980e...    9368171

# %% [markdown]
# ## Save to DB

# %%
db_url = 'sqlite:///data/spotify.db'

# %%
artist_df.to_sql('Artist', db_url, if_exists='replace', index=False)

# %% [markdown]
# ## Albums

# %%
album = sp.album('0PMasrHdpaoIRuHuhHp72O')
album
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3eqjTLE0HfPfh78zjh6TqT'},
#    'href': 'https://api.spotify.com/v1/artists/3eqjTLE0HfPfh78zjh6TqT',
#    'id': '3eqjTLE0HfPfh78zjh6TqT',
#    'name': 'Bruce Springsteen',
#    'type': 'artist',
#    'uri': 'spotify:artist:3eqjTLE0HfPfh78zjh6TqT'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
# ...

# %%
album['release_date'][:4]
# Out:
# '2021'

# %%
album['artists'][0]['id']
# Out:
# '6BH2lormtpjy3X9DyrGHVj'

# %%
album['name']
# Out:
# 'Bob Marley & Friends'

# %%
album['popularity']
# Out:
# 80

# %%
album['images'][0]['url']
# Out:
# 'https://i.scdn.co/image/ab67616d0000b273a995c97899829cbf180ff628'

# %%
albums = []
for artist in [bruce_sprinsteen, bob_marley]:
    results = sp.artist_albums(artist, album_type='album')
    
    albums.extend([sp.album(it['id']) for it in results['items']])
    while results['next']:
        results = sp.next(results)
        albums.extend([sp.album(it['id']) for it in results['items']])

# %%
albums_df = pd.DataFrame([{'id':album['id'], 
 'name': album['name'],
 'cover': album['images'][0]['url'],
 'year':album['release_date'][:4],
 'artist':album['artists'][0]['id'],
 'popularity':album['popularity'],
 'label':album['label'],} for album in albums])

# %%
albums_df.to_sql('Album', db_url, index=False, if_exists='replace')

# %% [markdown]
# ## Tracks

# %%
track_list = []
for album in albums:
    results = sp.album_tracks(album['id'])
    for t in results['items']: 
        track = sp.track(t['id'])
        track_list.append( {
              'id': track['id'],
              'album':  album['id'],
              'duration': round(track['duration_ms']/1000),
              'name': track['name'],
              'popularity': track['popularity']
            }) 
    while results['next']:
        results = sp.next(results)
        for t in results['items']:  
            track = sp.track(t['id'])
            track_list.append( {
                  'id': track['id'],
                  'album':  album['id'],
                  'duration': round(track['duration_ms']/1000),
                  'name': track['name'],
                  'popularity': track['popularity']
                })

# %%
pd.DataFrame(track_list).to_sql('Track', db_url, index=False, if_exists='replace')

# %%
sp.track('3S2bActYBlskH5gtanFIMO')
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3eqjTLE0HfPfh78zjh6TqT'},
#     'href': 'https://api.spotify.com/v1/artists/3eqjTLE0HfPfh78zjh6TqT',
#     'id': '3eqjTLE0HfPfh78zjh6TqT',
#     'name': 'Bruce Springsteen',
#     'type': 'artist',
#     'uri': 'spotify:artist:3eqjTLE0HfPfh78zjh6TqT'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
# ...

# %%
sp.album('5devPxQnSKVF2Ed0CVwQZh')
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3eqjTLE0HfPfh78zjh6TqT'},
#    'href': 'https://api.spotify.com/v1/artists/3eqjTLE0HfPfh78zjh6TqT',
#    'id': '3eqjTLE0HfPfh78zjh6TqT',
#    'name': 'Bruce Springsteen',
#    'type': 'artist',
#    'uri': 'spotify:artist:3eqjTLE0HfPfh78zjh6TqT'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
# ...

# %%
tracks = pd.DataFrame(track_list)

# %%
tracks.head()
# Out:
#                        id                   album  duration  \
# 0  4VpkCmCnqgcUcysgHdTbYf  5devPxQnSKVF2Ed0CVwQZh       178
# 1  4Ngh6rMVUCOFK30oO0iEMD  5devPxQnSKVF2Ed0CVwQZh       295
# 2  6iTvdHhfGD9Gu0eD7VNRkR  5devPxQnSKVF2Ed0CVwQZh       243
# 3  3S2bActYBlskH5gtanFIMO  5devPxQnSKVF2Ed0CVwQZh       409
# 4  1LQDe2LxhReHitq7sdgLcN  5devPxQnSKVF2Ed0CVwQZh       246
#
#                      name  popularity
# 0  One Minute You're Here          55
# 1           Letter To You          60
# 2           Burnin' Train          52
# 3   Janey Needs A Shooter          53
# 4       Last Man Standing          51
