# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# https://www.chicagoreader.com/chicago/BestOf?year=2019&category=1979894

# %%
# read in a page and convert requests text into 'soup' object
r = requests.get('https://www.chicagoreader.com/chicago/BestOf?year=2019&category=1979894')
soup = BeautifulSoup(r.text, "lxml")

# %%
# find the section of relevant links and then parse into iterable rows
links_section = soup.find(name='dl', attrs={'class':'boccat'})
link_rows = links_section.find_all(name='dd')

# %%
# create a list of category links
category_links = ['http://chicagoreader.com' + row.a['href'] for row in link_rows]
category_links
# Out:
# ['http://chicagoreader.com/chicago/BestOf?category=1979894&year=2011',
#  'http://chicagoreader.com/chicago/best-fancy-restaurant-in-chicago/BestOf?oid=4088017',
#  'http://chicagoreader.com/chicago/best-bang-for-your-buck/BestOf?oid=4088018',
#  'http://chicagoreader.com/chicago/best-chef/BestOf?oid=4088191',
#  'http://chicagoreader.com/chicago/best-up-and-coming-chef/BestOf?oid=4088225',
#  'http://chicagoreader.com/chicago/best-food-blog/BestOf?oid=4088227',
#  'http://chicagoreader.com/chicago/best-ampersand-restaurant/BestOf?oid=4088228',
#  'http://chicagoreader.com/chicago/best-restaurant-name/BestOf?oid=4088229',
#  'http://chicagoreader.com/chicago/best-new-food-trend/BestOf?oid=4088231',
#  'http://chicagoreader.com/chicago/best-cocktail-list/BestOf?oid=4088236',
#  'http://chicagoreader.com/chicago/best-mixologist/BestOf?oid=4088461',
#  'http://chicagoreader.com/chicago/best-wine-list/BestOf?oid=4088462',
#  'http://chicagoreader.com/chicago/best-sommelier/BestOf?oid=4088464',
#  'http://chicagoreader.com/chicago/best-brewpub/BestOf?oid=4088465',
#  'http://chicagoreader.com/chicago/best-local-brew/BestOf?oid=4088468',
#  'http://chicagoreader.com/chicago/best-wine-shop/BestOf?oid=4088469',
#  'http://chicagoreader.com/chicago/best-liquor-store/BestOf?oid=4088470',
#  'http://chicagoreader.com/chicago/best-byob/BestOf?oid=4088471',
#  'http://chicagoreader.com/chicago/best-alfresco-dining/BestOf?oid=4088472',
#  'http://chicagoreader.com/chicago/best-late-night/BestOf?oid=4088473',
#  'http://chicagoreader.com/chicago/best-for-kids/BestOf?oid=4088474',
#  'http://chicagoreader.com/chicago/best-waitstaff/BestOf?oid=4088476',
#  'http://chicagoreader.com/chicago/best-looking-waitstaff/BestOf?oid=4088477',
#  'http://chicagoreader.com/chicago/best-food-festival/BestOf?oid=4088478',
#  'http://chicagoreader.com/chicago/best-food-truck/BestOf?oid=4088479',
#  'http://chicagoreader.com/chicago/best-gourmet-market/BestOf?oid=4088529',
#  'http://chicagoreader.com/chicago/best-local-grocer/BestOf?oid=4088661',
#  'http://chicagoreader.com/chicago/best-local-food-product/BestOf?oid=4088662',
#  'http://chicagoreader.com/chicago/best-farmers-market/BestOf?oid=4088668',
#  'http://chicagoreader.com/chicago/best-butcher-shop/BestOf?oid=4088669',
#  'http://chicagoreader.com/chicago/best-cheesemonger/BestOf?oid=4088670',
#  'http://chicagoreader.com/chicago/best-barista/BestOf?oid=4088671',
#  'http://chicagoreader.com/chicago/best-restaurant-with-a-view/BestOf?oid=4088672',
#  'http://chicagoreader.com/chicago/best-restaurant-for-romance/BestOf?oid=4088674',
#  'http://chicagoreader.com/chicago/best-restaurant-for-a-cheap-date/BestOf?oid=4088679',
#  'http://chicagoreader.com/chicago/best-neighborhood-restaurant/BestOf?oid=4088680',
#  'http://chicagoreader.com/chicago/best-bagels/BestOf?oid=4088681',
#  'http://chicagoreader.com/chicago/best-bakery/BestOf?oid=4088697',
#  'http://chicagoreader.com/chicago/best-barbecue/BestOf?oid=4088858',
#  'http://chicagoreader.com/chicago/best-breakfast/BestOf?oid=4088859',
#  'http://chicagoreader.com/chicago/best-brunch/BestOf?oid=4088860',
#  'http://chicagoreader.com/chicago/best-burger/BestOf?oid=4088863',
#  'http://chicagoreader.com/chicago/best-chinese/BestOf?oid=4088864',
#  'http://chicagoreader.com/chicago/best-coffee-shop/BestOf?oid=4088867',
#  'http://chicagoreader.com/chicago/best-desserts/BestOf?oid=4088868',
#  'http://chicagoreader.com/chicago/best-greek/BestOf?oid=4088869',
#  'http://chicagoreader.com/chicago/best-hot-dog/BestOf?oid=4088870',
#  'http://chicagoreader.com/chicago/best-ice-cream/BestOf?oid=4088872',
#  'http://chicagoreader.com/chicago/best-indian-restaurant/BestOf?oid=4088873',
#  'http://chicagoreader.com/chicago/best-italian/BestOf?oid=4088875',
#  'http://chicagoreader.com/chicago/best-korean/BestOf?oid=4088876',
#  'http://chicagoreader.com/chicago/best-mexican/BestOf?oid=4092029',
#  'http://chicagoreader.com/chicago/best-middle-eastern/BestOf?oid=4092030',
#  'http://chicagoreader.com/chicago/best-pizza/BestOf?oid=4092032',
#  'http://chicagoreader.com/chicago/best-polish/BestOf?oid=4092033',
#  'http://chicagoreader.com/chicago/best-pub-grub/BestOf?oid=4092035',
#  'http://chicagoreader.com/chicago/best-sandwiches/BestOf?oid=4092038',
#  'http://chicagoreader.com/chicago/best-seafood-restaurant/BestOf?oid=4092160',
#  'http://chicagoreader.com/chicago/best-steak-house/BestOf?oid=4092253',
#  'http://chicagoreader.com/chicago/best-sushi/BestOf?oid=4092254',
#  'http://chicagoreader.com/chicago/best-taqueria/BestOf?oid=4092259',
#  'http://chicagoreader.com/chicago/best-thai/BestOf?oid=4092260',
#  'http://chicagoreader.com/chicago/best-vegetarian/BestOf?oid=4092261',
#  'http://chicagoreader.com/chicago/best-vietnamese/BestOf?oid=4092262',
#  'http://chicagoreader.com/chicago/best-italian-steak-house-where-my-dad-felt-at-home-in-the-60s-and-i-do-nowp/BestOf?oid=4101104',
#  'http://chicagoreader.com/chicago/best-case-of-nostalgia-bordering-on-time-travel/BestOf?oid=4101105',
#  'http://chicagoreader.com/chicago/best-restaurant-empire-founded-the-same-year-as-the-reader/BestOf?oid=4101106',
#  'http://chicagoreader.com/chicago/best-restaurant/BestOf?oid=4101107',
#  'http://chicagoreader.com/chicago/best-bargain-michelin-chef/BestOf?oid=4101108',
#  'http://chicagoreader.com/chicago/best-chef-downshift-animal-division/BestOf?oid=4101109',
#  'http://chicagoreader.com/chicago/best-chef-downshift-vegetable-division/BestOf?oid=4101385',
#  'http://chicagoreader.com/chicago/best-venerable-restaurant-alongside-the-el/BestOf?oid=4101386',
#  'http://chicagoreader.com/chicago/best-new-food-truckfood/BestOf?oid=4101387',
#  'http://chicagoreader.com/chicago/best-buffet/BestOf?oid=4101388',
#  'http://chicagoreader.com/chicago/best-game-day/BestOf?oid=4101389',
#  'http://chicagoreader.com/chicago/best-dairy-product-to-camp-out-in-front-of-the-cheese-shop-for/BestOf?oid=4101390',
#  'http://chicagoreader.com/chicago/best-use-of-alcohol-at-breakfast/BestOf?oid=4101391',
#  'http://chicagoreader.com/chicago/best-university-coffeehouse/BestOf?oid=4101393',
#  'http://chicagoreader.com/chicago/best-bakery-youve-never-heard-of/BestOf?oid=4101397',
#  'http://chicagoreader.com/chicago/best-place-to-see-bakers-at-work/BestOf?oid=4101398',
#  'http://chicagoreader.com/chicago/best-place-for-ambience-and-egg-sandwiches/BestOf?oid=4101399',
#  'http://chicagoreader.com/chicago/best-bagel/BestOf?oid=4101410',
#  'http://chicagoreader.com/chicago/best-tubular-collaboration/BestOf?oid=4101411',
#  'http://chicagoreader.com/chicago/best-sausage/BestOf?oid=4101412',
#  'http://chicagoreader.com/chicago/best-place-in-chicago-to-sample-salumi-from-mario-batalis-papa/BestOf?oid=4101413',
#  'http://chicagoreader.com/chicago/best-broccoli-and-shells-con-patio/BestOf?oid=4101414',
#  'http://chicagoreader.com/chicago/best-fancy-pants-pizza-special/BestOf?oid=4101415',
#  'http://chicagoreader.com/chicago/best-polish-mexican-american-150-taco/BestOf?oid=4101416',
#  'http://chicagoreader.com/chicago/best-tater-tots/BestOf?oid=4101417',
#  'http://chicagoreader.com/chicago/best-spinach-pie/BestOf?oid=4101419',
#  'http://chicagoreader.com/chicago/best-som-tam/BestOf?oid=4101420',
#  'http://chicagoreader.com/chicago/best-soundtracked-strawberry-shake/BestOf?oid=4101498',
#  'http://chicagoreader.com/chicago/best-newly-minted-if-loosely-defined-neighborhood-for-destination-dining/BestOf?oid=4101624',
#  'http://chicagoreader.com/chicago/best-hangout-after-a-day-at-rogers-parks-beaches/BestOf?oid=4101655',
#  'http://chicagoreader.com/chicago/best-few-square-blocks-to-eat-really-well-and-cheaply/BestOf?oid=4101657',
#  'http://chicagoreader.com/chicago/best-place-to-feel-bad-about-gentrification-but-good-about-your-meal/BestOf?oid=4101658',
#  'http://chicagoreader.com/chicago/best-restaurant-staff-bent-on-making-your-day/BestOf?oid=4101659',
#  'http://chicagoreader.com/chicago/best-one-woman-kitchen/BestOf?oid=4101660',
#  'http://chicagoreader.com/chicago/most-underrated-james-beard-award-winner/BestOf?oid=4101661',
#  'http://chicagoreader.com/chicago/best-new-food-blog/BestOf?oid=4101662',
#  'http://chicagoreader.com/chicago/best-food-blog-written-by-a-linguist/BestOf?oid=4101663',
#  'http://chicagoreader.com/chicago/best-place-to-eat-and-drink-for-a-good-cause/BestOf?oid=4101664',
#  'http://chicagoreader.com/chicago/best-csa-farmer-to-swoon-over/BestOf?oid=4101665',
#  'http://chicagoreader.com/chicago/best-canine-control-at-a-farmers-market/BestOf?oid=4101666',
#  'http://chicagoreader.com/chicago/best-craft-brewery-that-doesnt-exist-yet/BestOf?oid=4101667',
#  'http://chicagoreader.com/chicago/best-cocktail-book-club/BestOf?oid=4101668']

# %%
# function that takes a link and returns a dictionary of info about that page
def get_category_winners(category_link):
    r = requests.get(category_link)
    soup = BeautifulSoup(r.text, "lxml")
    return {"category":     soup.find(name='h1', attrs={'class':'headline'}).string,
            "winners":      [h2.string for h2 in soup.find_all(name='h2', attrs={'class':'boc1'})],
            "runners_up":   [h2.string for h2 in soup.find_all(name='h2', attrs={'class':'boc2'})]
            }

# %%
get_category_winners('http://chicagoreader.com/chicago/best-cocktail-book-club/BestOf?oid=4101668')
# Out:
# {'category': 'Best cocktail book club\xa0',
#  'winners': ['The Whistler'],
#  'runners_up': []}

# %%
# create list of dictionaries for the first three links
from time import sleep
from tqdm import tqdm

winners = []
for category_link in tqdm(category_links):
    winners.append(get_category_winners(category_link))

# 'pretty print' the winners data
from pprint import pprint
pprint(winners)
# Out:
# 100%|██████████| 106/106 [11:53<00:00,  6.73s/it]
# [{'category': "Best restaurant that's been around forever and is still worth "
#               'the trip\xa0',
#   'runners_up': ['Frontera Grill',
#                  'Chicago Diner  ',
#                  'Sabatino’s',
#                  'Twin Anchors'],
#   'winners': ['Lula Cafe']},
#  {'category': 'Best fancy restaurant in Chicago\xa0',
#   'runners_up': ['Blackbird', 'Girl & the Goat', 'Green Zebra', 'The Publican'],
#   'winners': ['Alinea ']},
#  {'category': 'Best bang for your buck\xa0',
#   'runners_up': ['Frasca Pizzeria & Wine Bar',
#                  'Chutney Joe’s',
#                  '"My boyfriend!"'],
#   'winners': ['Big Star', 'Sultan’s Market']},
#  {'category': 'Best chef\xa0',
#   'runners_up': ['Grant Achatz (Alinea, Next, The Aviary)',
#                  'Stephanie Izard (Girl & the Goat)'],
#   'winners': ['Rick Bayless (Frontera Grill, Topolobampo, Xoco)']},
#  {'category': 'Best up-and-coming chef\xa0',
#   'runners_up': ['Jimmy Bannos Jr., The Purple Pig',
#                  'Cesar Pineda, Ciao Amore Ristorante',
#                  'Rodney Staton, Bite Cafe'],
#   'winners': ['Jeremy Kiens, \nDunlays on Clark']},
#  {'category': 'Best food blog\xa0',
#   'runners_up': ['LTHForum', 'Sky Full of Bacon', '312 Dining Diva'],
#   'winners': ['Eater Chicago']},
#  {'category': 'Best ampersand restaurant\xa0',
#   'runners_up': ['Owen & Engine'],
#   'winners': ['Longman & Eagle ']},
#  {'category': 'Best restaurant name\xa0',
#   'runners_up': ['Cibo Matto', 'The Smoke Daddy'],
#   'winners': ['Girl & the Goat']},
#  {'category': 'Best new food trend\xa0',
#   'runners_up': ['Doughnuts',
#                  'Cupcakes',
#                  'Pork',
#                  'Gastropubs',
#                  'Small Plates',
#                  '“Eating at home”'],
#   'winners': ['Food trucks']},
#  {'category': 'Best cocktail list\xa0',
#   'runners_up': ['The Violet Hour', 'Sable Kitchen & Bar  '],
#   'winners': ['The Whistler']},
#  {'category': 'Best mixologist\xa0',
#   'runners_up': ['Jonny Abens, Roof on the Wit'],
#   'winners': ['Paul McGee, the Whistler']},
#  {'category': 'Best wine list\xa0',
#   'runners_up': ['Webster’s Wine Bar', 'Rootstock Wine & Beer Bar'],
#   'winners': ['DOC Winebar']},
#  {'category': 'Best sommelier\xa0',
#   'runners_up': ['Nick Luedde, The Tasting Room',
#                  'Jeremy Quinn, Webster’s Wine Bar',
#                  'Daniel Pilkey, Ria and Balsan '],
#   'winners': ['Alpana Singh']},
#  {'category': 'Best brewpub\xa0',
#   'runners_up': ['Goose Island Brewpub', 'Piece Brewery & Pizzeria'],
#   'winners': ['Revolution Brewing Company']},
#  {'category': 'Best local brew\xa0',
#   'runners_up': ['Goose Island 312 Urban Wheat Ale', 'Goose Island Matilda'],
#   'winners': ['Half Acre Daisy Cutter Pale Ale']},
#  {'category': 'Best wine shop\xa0',
#   'runners_up': ['In Fine Spirits', 'Life’s a Cabernet'],
#   'winners': ['Lush Wine & Spirits']},
#  {'category': 'Best liquor store\xa0',
#   'runners_up': ['Vas Foremost Liquors', 'West Lakeview Liquors'],
#   'winners': ['Binny’s Beverage Depot']},
#  {'category': 'Best BYOB\xa0',
#   'runners_up': ['Ciao Amore Ristorante',
#                  'Coast Sushi ',
#                  '90 Miles Cuban Cafe'],
#   'winners': ['Tango Sur']},
#  {'category': 'Best alfresco dining\xa0',
#   'runners_up': ['Roof on the Wit', 'Big Star'],
#   'winners': ['Piccolo Sogno']},
#  {'category': 'Best late night\xa0',
#   'runners_up': ['Pick Me Up Cafe', 'Big Star'],
#   'winners': ['Lockdown Bar & Grill']},
#  {'category': 'Best for kids\xa0',
#   'runners_up': ['Wishbone',
#                  'Ed Debevic’s',
#                  'Rainforest Cafe',
#                  '“To be locked in a cold, dark, soundproof room”'],
#   'winners': ['Frasca Pizzeria & Wine Bar ']},
#  {'category': 'Best waitstaff\xa0',
#   'runners_up': ['Frasca Pizzeria & Wine Bar', 'Ciao Amore Ristorante'],
#   'winners': ['Lockdown Bar & Grill']},
#  {'category': 'Best-looking waitstaff\xa0',
#   'runners_up': ['Longman & Eagle', 'Lula Cafe', 'Lockdown Bar & Grill'],
#   'winners': ['The Smoke Daddy']},
#  {'category': 'Best food festival\xa0',
#   'runners_up': ['Ribfest', 'Baconfest'],
#   'winners': ['Taste of Chicago']},
#  {'category': 'Best food truck\xa0',
#   'runners_up': ['Gaztro-Wagon ', 'The Southern Mac & Cheese Truck '],
#   'winners': ['Tamalli Space Charros']},
#  {'category': 'Best gourmet market\xa0',
#   'runners_up': ['Chicago French Market', 'Whole Foods Market'],
#   'winners': ['Fox & Obel']},
#  {'category': 'Best local grocer\xa0',
#   'runners_up': ['Dill Pickle Food Co-Op', 'Stanley’s Fruit & Vegetables'],
#   'winners': ['Green Grocer']},
#  {'category': 'Best local food product\xa0',
#   'runners_up': ['Nice Cream', 'Co-Op Hot Sauce'],
#   'winners': ['Vienna Beef Hot Dogs']},
#  {'category': "Best farmers' market\xa0",
#   'runners_up': ['Logan Square Farmers’ Market',
#                  'Lincoln Square Farmers’ Market'],
#   'winners': ['Green City Market']},
#  {'category': 'Best butcher shop\xa0',
#   'runners_up': ['The Butcher & Larder  ',
#                  'Gene’s Sausage Shop & Delicatessen',
#                  '“Fuck you, I’m a vegetarian!”'],
#   'winners': ['Paulina Meat Market']},
#  {'category': 'Best cheesemonger\xa0',
#   'runners_up': ['Marion Street Cheese Market', 'Whole Foods Market'],
#   'winners': ['Pastoral Artisan Cheese, Bread & Wine']},
#  {'category': 'Best barista\xa0',
#   'runners_up': ['Tim Ashorian, Bellezza Gelato Caffe',
#                  'Greg Wolfson, Bleeding Heart Bakery'],
#   'winners': ['Kristin Marks, Wormhole Coffee']},
#  {'category': 'Best restaurant with a view\xa0',
#   'runners_up': ['Roof on the Wit', 'NoMi Kitchen'],
#   'winners': ['The Signature Room at the 95th']},
#  {'category': 'Best restaurant for romance\xa0',
#   'runners_up': ['Between Boutique Cafe & Lounge',
#                  'DOC Wine Bar ',
#                  '“I wouldn’t know—apparently Chicago’s ladies don’t like '
#                  'me.”'],
#   'winners': ['Geja’s Cafe']},
#  {'category': 'Best restaurant for a cheap date\xa0',
#   'runners_up': ['The Smoke Daddy', 'Irazu'],
#   'winners': ['Big Star']},
#  {'category': 'Best neighborhood restaurant\xa0',
#   'runners_up': ['Dunlays on Clark', 'Ciao Amore Ristorante'],
#   'winners': ['Lula Cafe']},
#  {'category': 'Best bagels\xa0',
#   'runners_up': ['Bagel on Damen', 'Chicago Bagel Authority'],
#   'winners': ['New York Bagel & Bialy']},
#  {'category': 'Best bakery\xa0',
#   'runners_up': ['Dinkel’s Bakery', 'Sweet Mandy B’s'],
#   'winners': ['Bleeding Heart Bakery']},
#  {'category': 'Best barbecue\xa0',
#   'runners_up': ['The Smoke Daddy', 'Honky Tonk Barbeque'],
#   'winners': ['Smoque']},
#  {'category': 'Best breakfast\xa0',
#   'runners_up': ['Bongo Room', 'Over Easy Cafe'],
#   'winners': ['M. Henry']},
#  {'category': 'Best brunch\xa0',
#   'runners_up': ['M. Henry', "Tweet Let's Eat"],
#   'winners': ['Lula Cafe']},
#  {'category': 'Best burger\xa0',
#   'runners_up': ['Lockdown Bar & Grill', 'DMK Burger Bar'],
#   'winners': ['Kuma’s Corner']},
#  {'category': 'Best Chinese\xa0',
#   'runners_up': ['Friendship Chinese Restaurant', 'Sun Wah Bar-B-Que'],
#   'winners': ['Lao Sze Chuan']},
#  {'category': 'Best coffee shop\xa0',
#   'runners_up': ['Bellezza Gelato Caffe', 'Wormhole Coffee'],
#   'winners': ['Intelligentsia Coffee and Tea']},
#  {'category': 'Best desserts\xa0',
#   'runners_up': ['Bleeding Heart Bakery', 'Dunlays on Clark'],
#   'winners': ['Hot Chocolate']},
#  {'category': 'Best Greek\xa0',
#   'runners_up': ['Athenian Room', 'Athena', 'The Parthenon'],
#   'winners': ['Greek Islands']},
#  {'category': 'Best hot dog\xa0',
#   'runners_up': ['Superdawg', 'Portillo’s Hot Dogs'],
#   'winners': ['Hot Doug’s']},
#  {'category': 'Best ice cream\xa0',
#   'runners_up': ['Black Dog Gelato', 'Bellezza Gelato Cafe'],
#   'winners': ['Margie’s Candies']},
#  {'category': 'Best Indian restaurant\xa0',
#   'runners_up': ['Hema’s Kitchen', 'Cumin', 'Marigold'],
#   'winners': ['Chutney Joe’s']},
#  {'category': 'Best Italian\xa0',
#   'runners_up': ['Ciao Amore Ristorante',
#                  'Frasca Pizzeria & Wine Bar',
#                  'Mia Francesca'],
#   'winners': ['Cibo Matto']},
#  {'category': 'Best Korean\xa0',
#   'runners_up': ['Cho Sun Ok Restaurant', 'Jin Ju'],
#   'winners': ['San Soo Gab San']},
#  {'category': 'Best Mexican\xa0',
#   'runners_up': ['Nuevo Leon', 'El Cid'],
#   'winners': ['Frontera Grill']},
#  {'category': 'Best Middle Eastern\xa0',
#   'runners_up': ['Reza’s', 'Noon-O-Kabab'],
#   'winners': ['Sultan’s Market']},
#  {'category': 'Best pizza\xa0',
#   'runners_up': ['Piece', 'Pequod’s', 'Art of Pizza'],
#   'winners': ['Lou Malnati’s']},
#  {'category': 'Best Polish\xa0',
#   'runners_up': [],
#   'winners': ['Podhalanka Polska Restauracja ', 'Red Apple']},
#  {'category': 'Best pub grub\xa0',
#   'runners_up': ['Revolution Brewing Company', 'Small Bar', 'Owen & Engine'],
#   'winners': ['Hopleaf']},
#  {'category': 'Best sandwiches\xa0',
#   'runners_up': ['Bari Foods', 'Hannah’s Bretzel'],
#   'winners': ['Jerry’s']},
#  {'category': 'Best seafood restaurant\xa0',
#   'runners_up': ['Joe’s Seafood, Prime Steak and Stone Crab ',
#                  'Glenn’s Diner',
#                  'GT Fish & Oyster'],
#   'winners': ['Shaw’s Crab House']},
#  {'category': 'Best steak house\xa0',
#   'runners_up': ['David Burke’s Primehouse',
#                  'Chicago Cut Steakhouse',
#                  'Gene & Georgetti'],
#   'winners': ['Gibsons']},
#  {'category': 'Best sushi\xa0',
#   'runners_up': ['Coast Sushi', 'Arami'],
#   'winners': ['Tank Sushi']},
#  {'category': 'Best taqueria\xa0',
#   'runners_up': ['La Pasadita ', 'Taqueria Moran'],
#   'winners': ['Big Star']},
#  {'category': 'Best Thai\xa0',
#   'runners_up': ['Sticky Rice Thai', 'Spoon Thai'],
#   'winners': ['Opart Thai House']},
#  {'category': 'Best vegetarian\xa0',
#   'runners_up': ['The Handlebar', 'Green Zebra'],
#   'winners': ['Chicago Diner']},
#  {'category': 'Best Vietnamese\xa0',
#   'runners_up': ['Hai Yen', 'RunPho 777', 'Nhu Lan Bakery'],
#   'winners': ['Tank Noodle']},
#  {'category': 'Best Italian steak house where my dad felt at home in the 60s '
#               'and I do now\xa0',
#   'runners_up': [],
#   'winners': ['Gene & Georgetti']},
#  {'category': 'Best case of nostalgia, bordering on time travel\xa0',
#   'runners_up': [],
#   'winners': ['Wormhole Coffee']},
#  {'category': None,
#   'runners_up': [],
#   'winners': ['Lettuce Entertain You Enterprises']},
#  {'category': 'Best restaurant\xa0', 'runners_up': [], 'winners': ['Next']},
#  {'category': 'Best bargain Michelin chef\xa0',
#   'runners_up': [],
#   'winners': ['Danny Grant, Balsan']},
#  {'category': 'Best chef downshift, animal division\xa0',
#   'runners_up': [],
#   'winners': ['Rob Levitt, the Butcher & Larder']},
#  {'category': 'Best chef downshift, vegetable division\xa0',
#   'runners_up': [],
#   'winners': ['Art Jackson, Pleasant House Bakery']},
#  {'category': 'Best venerable restaurant alongside the el\xa0',
#   'runners_up': [],
#   'winners': ["Daley's Restaurant"]},
#  {'category': 'Best new food truck\xa0',
#   'runners_up': [],
#   'winners': ['The Southern Mac Truck']},
#  {'category': 'Best buffet\xa0',
#   'runners_up': [],
#   'winners': ["Ruby's Fast Food"]},
#  {'category': 'Best game day\xa0',
#   'runners_up': [],
#   'winners': ['Harvard Hunting Club Game Dinner']},
#  {'category': 'Best dairy product to camp out in front of the cheese shop '
#               'for\xa0',
#   'runners_up': [],
#   'winners': ["Uplands Cheese's Rush Creek Reserve"]},
#  {'category': 'Best use of alcohol at breakfast\xa0',
#   'runners_up': [],
#   'winners': ["Burton's Maplewood Farm rum-infused maple syrup"]},
#  {'category': 'Best university coffeehouse\xa0',
#   'runners_up': [],
#   'winners': ['Hallowed Grounds']},
#  {'category': "Best bakery you've never heard of\xa0",
#   'runners_up': [],
#   'winners': ['Pastel Bakery']},
#  {'category': 'Best place to see bakers at work\xa0',
#   'runners_up': [],
#   'winners': ['Floriole Cafe and Bakery']},
#  {'category': 'Best place for ambience and egg sandwiches\xa0',
#   'runners_up': [],
#   'winners': ['Billy Goat Tavern']},
#  {'category': 'Best bagel\xa0',
#   'runners_up': [],
#   'winners': ['New York Bagel & Bialy']},
#  {'category': 'Best tubular collaboration\xa0',
#   'runners_up': [],
#   'winners': ["Lil' Johnny's birria sausages"]},
#  {'category': 'Best sausage\xa0',
#   'runners_up': [],
#   'winners': ['Bobak Sausage Company']},
#  {'category': "Best place in Chicago to sample salumi from Mario Batali's "
#               'papa\xa0',
#   'runners_up': [],
#   'winners': ['694 Wine & Spirits']},
#  {'category': 'Best broccoli and shells con patio\xa0',
#   'runners_up': [],
#   'winners': ["Tufano's Vernon Park Tap"]},
#  {'category': 'Best fancy-pants pizza special\xa0',
#   'runners_up': [],
#   'winners': ['Three Aces']},
#  {'category': 'Best Polish-Mexican-American $1.50 taco\xa0',
#   'runners_up': [],
#   'winners': ['Loncars Liquors']},
#  {'category': 'Best tater tots\xa0',
#   'runners_up': [],
#   'winners': ['The Rocking Horse']},
#  {'category': 'Best spinach pie\xa0',
#   'runners_up': [],
#   'winners': ['Taza Bakery']},
#  {'category': 'Best som tam\xa0', 'runners_up': [], 'winners': ['TAC Quick']},
#  {'category': 'Best soundtracked strawberry shake\xa0',
#   'runners_up': [],
#   'winners': ['M Burger']},
#  {'category': 'Best newly minted (if loosely defined) neighborhood for '
#               'destination dining\xa0',
#   'runners_up': [],
#   'winners': ['Noble Square']},
#  {'category': "Best hangout after a day at Rogers Park's beaches\xa0",
#   'runners_up': [],
#   'winners': ['RoPa Restaurant & Wine Bar']},
#  {'category': 'Best few square blocks to eat really well, and cheaply\xa0',
#   'runners_up': [],
#   'winners': ['Lawrence between Rockwell and California']},
#  {'category': 'Best place to feel bad about gentrification but good about your '
#               'meal\xa0',
#   'runners_up': [],
#   'winners': ['M. Henrietta']},
#  {'category': 'Best restaurant staff bent on making your day\xa0',
#   'runners_up': [],
#   'winners': ['Birchwood Kitchen']},
#  {'category': 'Best one-woman kitchen\xa0',
#   'runners_up': [],
#   'winners': ['Noon Hour Grill']},
#  {'category': 'Most underrated James Beard Award winner\xa0',
#   'runners_up': [],
#   'winners': ['Justin Kaufmann, WBEZ']},
#  {'category': 'Best new food blog\xa0',
#   'runners_up': [],
#   'winners': ['mariobatalivoice.blogspot.com']},
#  {'category': 'Best food blog written by a linguist\xa0',
#   'runners_up': [],
#   'winners': ['shesimmers.com']},
#  {'category': 'Best place to eat and drink for a good cause\xa0',
#   'runners_up': [],
#   'winners': ['Blue Sky Bakery & Cafe']},
#  {'category': 'Best CSA farmer to swoon over\xa0',
#   'runners_up': [],
#   'winners': ['Rob Montalbano of Montalbano Farms']},
#  {'category': "Best canine control at a farmers' market\xa0",
#   'runners_up': [],
#   'winners': ['Glenwood Sunday Market\n']},
#  {'category': "Best craft brewery that doesn't exist yet\xa0",
#   'runners_up': [],
#   'winners': ['Pipeworks']},
#  {'category': 'Best cocktail book club\xa0',
#   'runners_up': [],
#   'winners': ['The Whistler']}]

# %%
import pandas as pd

# %%
pd.DataFrame(winners)
# Out:
#                                               category  \
# 0    Best restaurant that's been around forever and...
# 1                    Best fancy restaurant in Chicago
# 2                             Best bang for your buck
# 3                                           Best chef
# 4                             Best up-and-coming chef
# ..                                                 ...
# 101      Best place to eat and drink for a good cause
# 102                     Best CSA farmer to swoon over
# 103          Best canine control at a farmers' market
# 104         Best craft brewery that doesn't exist yet
# 105                           Best cocktail book club
#
#                                                winners  \
# 0                                          [Lula Cafe]
# 1                                            [Alinea ]
# 2                          [Big Star, Sultan’s Market]
# 3    [Rick Bayless (Frontera Grill, Topolobampo, Xo...
# 4                   [Jeremy Kiens, \nDunlays on Clark]
# ..                                                 ...
# 101                           [Blue Sky Bakery & Cafe]
# 102               [Rob Montalbano of Montalbano Farms]
# 103                         [Glenwood Sunday Market\n]
# 104                                        [Pipeworks]
# 105                                     [The Whistler]
#
#                                             runners_up
# 0    [Frontera Grill, Chicago Diner  , Sabatino’s, ...
# 1    [Blackbird, Girl & the Goat, Green Zebra, The ...
# 2    [Frasca Pizzeria & Wine Bar, Chutney Joe’s, "M...
# 3    [Grant Achatz (Alinea, Next, The Aviary), Step...
# 4    [Jimmy Bannos Jr., The Purple Pig, Cesar Pined...
# ..                                                 ...
# 101                                                 []
# 102                                                 []
# 103                                                 []
# 104                                                 []
# 105                                                 []
#
# [106 rows x 3 columns]
