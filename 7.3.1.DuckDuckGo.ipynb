# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import requests

# %%
from selenium import webdriver

# %%
import geckodriver_autoinstaller
geckodriver_autoinstaller.install()
# Out:
# '/home/bioinformatica/.local/share/virtualenvs/Ironhack-OdDBNwqQ/lib/python3.7/site-packages/geckodriver_autoinstaller/v0.29.0/geckodriver'

# %%
driver = webdriver.Firefox()

# %%
driver.get('http://duckduckgo.com')

# %%
query_box = driver.find_element_by_id('search_form_input_homepage')

# %%
query_box
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="caf5e281-f552-4d7e-836d-4b81a7cee8ba", element="164428fa-bc25-42d4-b149-fe8785516723")>

# %%
query_box.click()

# %%
query_box.send_keys('Ironhack')

# %%
boton = driver.find_element_by_id('search_button_homepage')

# %%
boton.click()

# %%
for i in range(10):
    try:
        mas_resultados = driver.find_element_by_class_name('result--more__btn')
        mas_resultados.click()
    except:
        break

# %%
results = driver.find_elements_by_class_name('result__a')

# %%
for link in results:
    print(link.text)
    print(link.get_attribute('href'))
# Out:
# Bootcamps de desarrollo web, análisis de datos ... - Ironhack
# https://www.ironhack.com/es
# Bootcamp De Data Analytics
# https://www.ironhack.com/es/data-analytics
# Ironhack Web Development Bootcamp & Ux/Ui Design Bootcamp
# https://www.ironhack.com/es/desarrollo-web
# Contacto
# https://www.ironhack.com/es/contacto
# Español
# https://www.ironhack.com/es/alumni
# Apoyo Profesional
# https://www.ironhack.com/es/apoyo-profesional
# Contrata Talento
# https://www.ironhack.com/es/contratar
# Learn Web Development, Data Analytics & UX/UI ... - Ironhack
# https://www.ironhack.com/en
# Becas Santander Tech | Coding Academy - Ironhack
# https://www.becas-santander.com/es/program/becas-santander-tech-or-coding-academy-ironhack
# Becas Santander Tech | Digital Reskilling - Ironhack
# https://www.becas-santander.com/en/program/tech-digital-reskilling-ironhack
# Ironhack Madrid (Madrid, España) | Meetup
# https://www.meetup.com/es-ES/ironhack-madrid/
# Ironhack - Home | Facebook
# ...

# %%
mas_resultados = driver.find_element_by_class_name('result--more__btn')

# %%
mas_resultados.click()
